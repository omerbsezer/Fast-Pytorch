# %%
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.autograd import Variable

# %%
input_size=784
hidden_size=400
output_size=10
epochs=10
batch_size=100
learning_rate=0.001

# %%
train_dataset= datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset=datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# %%
train_loader=torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader=torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
class Net(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super(Net,self).__init__()
    self.fc1=nn.Linear(input_size,hidden_size) # 1. layer
    self.relu=nn.ReLU() 
    self.fc2=nn.Linear(hidden_size, hidden_size) # 2.layer
    self.fc3=nn.Linear(hidden_size, output_size)# 3. layer
    
  def forward(self,x):
    output=self.fc1(x)
    output=self.relu(output)
    output=self.fc2(output)
    output=self.relu(output)
    output=self.fc3(output)
    return output

# %%
net=Net(input_size, hidden_size, output_size)
CUDA=torch.cuda.is_available()
if CUDA:
  net=net.cuda()

# %%
#print(list(net.parameters()))
net.parameters
# Out:
# <bound method Module.parameters of Net(
#   (fc1): Linear(in_features=784, out_features=400, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=400, out_features=400, bias=True)
#   (fc3): Linear(in_features=400, out_features=10, bias=True)
# )>

# %%
# Loss and optimizer
criterion=nn.CrossEntropyLoss() # classification problem, more than 2 classifications
optimizer=torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# training
correct_train=0
total_train=0
for epoch in range(epochs):
  for i, (images, labels) in enumerate(train_loader):
    images=Variable(images.view(-1,28*28)) # flatten image data
    labels=Variable(labels)
    if CUDA: # transfer to CUDA
      images=images.cuda()
      labels=labels.cuda()
    optimizer.zero_grad() # clear param_grad in eq. param=param-(lr*pram_grad)
    outputs=net(images) # forward pass
    max_predicted_data, predicted= torch.max(outputs.data,1) # find the max of softmax and map the predicted list
    
    total_train+=labels.size(0) # increment batch size
    
    if CUDA: 
      correct_train+=(predicted.cpu()==labels.cpu()).sum() # sum() function works only on CPU, not on GPU  
    else:
      correct_train+=(predicted==labels).sum()
     
    loss=criterion(outputs,labels) # loss 
    loss.backward() # backpropagation

    optimizer.step() # update weights
    
    if(i+1)%100==0:
      #print('Epoch [{}/{}], Iteration [{}/{}]%'.format
      #     (epoch+1,epochs, i+1,len(train_dataset)//batch_size))
      print('Epoch [{}/{}], Iteration [{}/{}], Training Loss:{}, Training Accuracy:{}%'.format
           (epoch+1,epochs, i+1,len(train_dataset)//batch_size, loss.data, (100*correct_train/total_train)))
print("Training model is finished!")
# Out:
# Epoch [1/10], Iteration [100/600], Training Loss:0.09528876096010208, Training Accuracy:96%
# Epoch [1/10], Iteration [200/600], Training Loss:0.20748241245746613, Training Accuracy:96%
# Epoch [1/10], Iteration [300/600], Training Loss:0.10818041115999222, Training Accuracy:96%
# Epoch [1/10], Iteration [400/600], Training Loss:0.04674253612756729, Training Accuracy:96%
# Epoch [1/10], Iteration [500/600], Training Loss:0.10555576533079147, Training Accuracy:96%
# Epoch [1/10], Iteration [600/600], Training Loss:0.08904946595430374, Training Accuracy:97%
# Epoch [2/10], Iteration [100/600], Training Loss:0.04823092371225357, Training Accuracy:97%
# Epoch [2/10], Iteration [200/600], Training Loss:0.04080823436379433, Training Accuracy:97%
# Epoch [2/10], Iteration [300/600], Training Loss:0.04175937548279762, Training Accuracy:97%
# Epoch [2/10], Iteration [400/600], Training Loss:0.024706119671463966, Training Accuracy:97%
# Epoch [2/10], Iteration [500/600], Training Loss:0.019872425124049187, Training Accuracy:97%
# Epoch [2/10], Iteration [600/600], Training Loss:0.05335857719182968, Training Accuracy:97%
# Epoch [3/10], Iteration [100/600], Training Loss:0.007635135669261217, Training Accuracy:97%
# Epoch [3/10], Iteration [200/600], Training Loss:0.0519610196352005, Training Accuracy:97%
# Epoch [3/10], Iteration [300/600], Training Loss:0.01941787637770176, Training Accuracy:97%
# Epoch [3/10], Iteration [400/600], Training Loss:0.03344477340579033, Training Accuracy:97%
# Epoch [3/10], Iteration [500/600], Training Loss:0.015115887857973576, Training Accuracy:97%
# Epoch [3/10], Iteration [600/600], Training Loss:0.08114910125732422, Training Accuracy:97%
# Epoch [4/10], Iteration [100/600], Training Loss:0.05713411420583725, Training Accuracy:97%
# Epoch [4/10], Iteration [200/600], Training Loss:0.009925217367708683, Training Accuracy:98%
# Epoch [4/10], Iteration [300/600], Training Loss:0.006035451777279377, Training Accuracy:98%
# Epoch [4/10], Iteration [400/600], Training Loss:0.024433262646198273, Training Accuracy:98%
# Epoch [4/10], Iteration [500/600], Training Loss:0.01667332649230957, Training Accuracy:98%
# Epoch [4/10], Iteration [600/600], Training Loss:0.04025423899292946, Training Accuracy:98%
# Epoch [5/10], Iteration [100/600], Training Loss:0.007594199385493994, Training Accuracy:98%
# Epoch [5/10], Iteration [200/600], Training Loss:0.019686859101057053, Training Accuracy:98%
# Epoch [5/10], Iteration [300/600], Training Loss:0.00202755443751812, Training Accuracy:98%
# Epoch [5/10], Iteration [400/600], Training Loss:0.036345262080430984, Training Accuracy:98%
# Epoch [5/10], Iteration [500/600], Training Loss:0.1979316920042038, Training Accuracy:98%
# Epoch [5/10], Iteration [600/600], Training Loss:0.01660110242664814, Training Accuracy:98%
# Epoch [6/10], Iteration [100/600], Training Loss:0.024946732446551323, Training Accuracy:98%
# Epoch [6/10], Iteration [200/600], Training Loss:0.06363639235496521, Training Accuracy:98%
# Epoch [6/10], Iteration [300/600], Training Loss:0.01580067165195942, Training Accuracy:98%
# Epoch [6/10], Iteration [400/600], Training Loss:0.009617481380701065, Training Accuracy:98%
# Epoch [6/10], Iteration [500/600], Training Loss:0.0038027213886380196, Training Accuracy:98%
# Epoch [6/10], Iteration [600/600], Training Loss:0.008374066092073917, Training Accuracy:98%
# Epoch [7/10], Iteration [100/600], Training Loss:0.02591550536453724, Training Accuracy:98%
# Epoch [7/10], Iteration [200/600], Training Loss:0.01638486422598362, Training Accuracy:98%
# Epoch [7/10], Iteration [300/600], Training Loss:0.031541794538497925, Training Accuracy:98%
# Epoch [7/10], Iteration [400/600], Training Loss:0.002880158368498087, Training Accuracy:98%
# Epoch [7/10], Iteration [500/600], Training Loss:0.00130027299746871, Training Accuracy:98%
# Epoch [7/10], Iteration [600/600], Training Loss:0.03246097266674042, Training Accuracy:98%
# Epoch [8/10], Iteration [100/600], Training Loss:0.03337804600596428, Training Accuracy:98%
# Epoch [8/10], Iteration [200/600], Training Loss:0.002438678639009595, Training Accuracy:98%
# Epoch [8/10], Iteration [300/600], Training Loss:0.00154168123845011, Training Accuracy:98%
# Epoch [8/10], Iteration [400/600], Training Loss:0.0010143232066184282, Training Accuracy:98%
# Epoch [8/10], Iteration [500/600], Training Loss:0.006281463894993067, Training Accuracy:98%
# Epoch [8/10], Iteration [600/600], Training Loss:0.08235614001750946, Training Accuracy:98%
# Epoch [9/10], Iteration [100/600], Training Loss:0.0015307903522625566, Training Accuracy:98%
# Epoch [9/10], Iteration [200/600], Training Loss:0.00743183633312583, Training Accuracy:98%
# Epoch [9/10], Iteration [300/600], Training Loss:0.0247410349547863, Training Accuracy:98%
# Epoch [9/10], Iteration [400/600], Training Loss:0.017143139615654945, Training Accuracy:98%
# Epoch [9/10], Iteration [500/600], Training Loss:0.0031053591519594193, Training Accuracy:98%
# Epoch [9/10], Iteration [600/600], Training Loss:0.013609629124403, Training Accuracy:98%
# Epoch [10/10], Iteration [100/600], Training Loss:0.0005715226870961487, Training Accuracy:98%
# Epoch [10/10], Iteration [200/600], Training Loss:0.013618402183055878, Training Accuracy:98%
# Epoch [10/10], Iteration [300/600], Training Loss:0.0012653255835175514, Training Accuracy:98%
# Epoch [10/10], Iteration [400/600], Training Loss:0.0012201261706650257, Training Accuracy:98%
# Epoch [10/10], Iteration [500/600], Training Loss:0.01468532532453537, Training Accuracy:98%
# Epoch [10/10], Iteration [600/600], Training Loss:0.03462210297584534, Training Accuracy:98%
# Training model is finished!

# %%
# test
correct=0
total=0
for images, labels in test_loader:
  images=Variable(images.view(-1,28*28))
  if CUDA:
    images=images.cuda()
  outputs=net(images)
  _,predicted=torch.max(outputs.data,1)
  total+=labels.size(0)
  if CUDA:
    correct+=(predicted.cpu()==labels.cpu()).sum()
  else:
    correct+=(predicted==labels).sum()
  print("Test Accuracy: %d " % (100*correct/total))
# Out:
# Test Accuracy: 100
# Test Accuracy: 98
# Test Accuracy: 98
# Test Accuracy: 98
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 96
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 96
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 98
# Test Accuracy: 98
# Test Accuracy: 98
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
# Test Accuracy: 97
